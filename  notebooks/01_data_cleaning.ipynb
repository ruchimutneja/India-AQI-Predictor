# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 50)
df = pd.read_csv('city_day.csv')
print(df.shape)
display(df.head())
print(df.dtypes)
# Out:
# (29531, 16)
#         City        Date  PM2.5  PM10     NO    NO2    NOx  NH3     CO    SO2  \
# 0  Ahmedabad  2015-01-01    NaN   NaN   0.92  18.22  17.15  NaN   0.92  27.64
# 1  Ahmedabad  2015-01-02    NaN   NaN   0.97  15.69  16.46  NaN   0.97  24.55
# 2  Ahmedabad  2015-01-03    NaN   NaN  17.40  19.30  29.70  NaN  17.40  29.07
# 3  Ahmedabad  2015-01-04    NaN   NaN   1.70  18.48  17.97  NaN   1.70  18.59
# 4  Ahmedabad  2015-01-05    NaN   NaN  22.10  21.42  37.76  NaN  22.10  39.33
#
#        O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  133.36     0.00     0.02    0.00  NaN        NaN
# 1   34.06     3.68     5.50    3.77  NaN        NaN
# 2   30.70     6.80    16.40    2.25  NaN        NaN
# 3   36.08     4.43    10.14    1.00  NaN        NaN
# 4   39.31     7.01    18.89    2.78  NaN        NaN
# City              str
# Date              str
# PM2.5         float64
# PM10          float64
# NO            float64
# NO2           float64
# NOx           float64
# NH3           float64
# CO            float64
# SO2           float64
# O3            float64
# Benzene       float64
# Toluene       float64
# Xylene        float64
# AQI           float64
# AQI_Bucket        str
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
hyd = (
    df[df['City'].str.strip().str.lower() == 'hyderabad']
    .sort_values('Date')
    .drop_duplicates(subset=['Date'])
    .set_index('Date')
)

print(hyd.index.min(), hyd.index.max())
# Out:
# 2015-01-04 00:00:00 2020-07-01 00:00:00

# %%
print(hyd.shape)
display(hyd.head())
# Out:
# (2006, 15)
#                  City  PM2.5  PM10     NO    NO2    NOx  NH3    CO   SO2  \
# Date
# 2015-01-04  Hyderabad    NaN   NaN   3.70  17.19  20.89  NaN  0.30  2.58
# 2015-01-05  Hyderabad    NaN   NaN   3.61   9.69  13.30  NaN  0.23  5.19
# 2015-01-06  Hyderabad    NaN   NaN   4.21  22.02  26.23  NaN  0.31  9.09
# 2015-01-07  Hyderabad    NaN   NaN  26.08  40.08  66.15  NaN  0.53  9.03
# 2015-01-08  Hyderabad    NaN   NaN  10.31  33.02  43.33  NaN  0.44  8.47
#
#                O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# Date
# 2015-01-04  30.34     0.41     6.15    1.11  NaN        NaN
# 2015-01-05  31.28     0.39     7.22    0.55  NaN        NaN
# 2015-01-06  28.56     0.52     5.14    0.53  NaN        NaN
# 2015-01-07  31.08     1.92    16.35    2.14  NaN        NaN
# 2015-01-08  35.72     1.89    14.27    1.58  NaN        NaN

# %%
missing = hyd.isna().mean().sort_values(ascending=False)
display((missing * 100).round(1).to_frame('missing_percent'))
hyd.head(30)
# Out:
#        missing_percent
# PM10              12.4
# AQI                0.0
# PM2.5              0.0
# NO2                0.0
# CO                 0.0
# O3                 0.0
#               AQI     PM2.5  PM10    NO2    CO      O3
# Date
# 2015-03-31  120.0   47.0300   NaN  16.94  0.81  25.130
# 2015-04-01  112.0   40.6200   NaN  13.18  0.81  34.190
# 2015-04-02  117.8   43.1825   NaN  14.34  0.85  31.970
# 2015-04-03  123.6   45.7450   NaN  22.86  1.07  36.150
# 2015-04-06  141.0   83.0000   NaN  12.91  0.89  33.670
# 2015-04-07  197.0  112.2100   NaN  17.06  1.05  30.680
# 2015-04-08  177.0   38.6700   NaN   9.28  0.73  23.530
# 2015-04-09  104.0   33.8800   NaN  13.18  0.80  21.580
# 2015-04-10  106.0   30.8800   NaN  12.34  0.76  22.800
# 2015-04-11  105.0   42.8800   NaN  17.22  0.87  32.930
# 2015-04-12  128.0   26.3800   NaN   8.78  1.41  32.860
# 2015-04-13  133.0   56.3900   NaN  13.36  1.13  40.110
# 2015-04-14  312.0  158.3200   NaN  20.35  0.95  40.520
# 2015-04-15  179.0   44.7900   NaN  15.29  0.80  30.830
# 2015-04-16  112.0   30.2100   NaN  12.22  0.76  33.590
# 2015-04-17  106.0   39.0400   NaN  15.82  0.84  39.940
# 2015-04-18  147.0   76.0000   NaN  33.56  1.30  35.280
# 2015-04-19  139.0   54.2500   NaN  21.04  1.00  41.520
# 2015-04-20  118.0   41.3800   NaN  15.76  0.86  32.440
# 2015-04-21  123.0   75.0800   NaN  15.17  0.81  29.910
# 2015-04-22  157.0   39.7100   NaN  18.78  1.02  23.510
# 2015-04-23  149.0   87.5400   NaN  17.45  1.14  37.940
# 2015-04-24  165.0   39.3800   NaN  12.68  0.76  42.520
# 2015-04-25  119.0   35.6100   NaN   7.42  0.81  51.440
# 2015-04-26   98.0   38.1950   NaN  17.87  0.85  45.375
# 2015-04-27   86.0   40.7800   NaN  28.32  0.89  39.310
# 2015-04-28  124.0   46.6200   NaN  18.93  0.83  39.740
# 2015-04-29  148.0   94.2900   NaN  18.65  0.72  38.940
# 2015-04-30  176.0   53.7900   NaN  19.14  1.01  52.570
# 2015-05-01  206.0   89.6200   NaN  29.62  1.41  38.940

# %%
wanted = ['AQI', 'PM2.5', 'PM10', 'NO2', 'CO', 'O3']
hyd = hyd[wanted].copy()

for column in wanted:
    hyd[column] = pd.to_numeric(hyd[column], errors='coerce')

print(hyd.head())
print(hyd.describe().T)
# Out:
#               AQI      PM2.5  PM10        NO2    CO         O3
# Date
# 2015-03-31  120.0  47.030000   NaN  16.940000  0.81  25.130000
# 2015-04-01  112.0  40.620000   NaN  13.180000  0.81  34.190000
# 2015-04-02  117.8  43.182500   NaN  14.340000  0.85  31.970000
# 2015-04-03  123.6  45.745000   NaN  22.860000  1.07  36.150000
# 2015-04-04  129.4  58.163333   NaN  19.543333  1.01  35.323333
#         count        mean        std    min      25%      50%       75%  \
# AQI    1904.0  109.120423  52.897481  22.00  75.0000  104.000  130.0000
# PM2.5  1904.0   46.981634  38.441247   4.83  25.7900   42.000   61.4125
# PM10   1672.0   91.624919  40.458335  10.54  61.3950   94.220  117.0200
# NO2    1904.0   28.527697  16.079470   0.62  15.3350   25.855   39.1575
# CO     1904.0    0.599465   0.523613   0.00   0.3300    0.570    0.7800
# O3     1904.0   33.747555  15.046052   0.10  22.4475   32.110   43.5425
#
#           max
# AQI    737.00
# PM2.5  571.02
# PM10   485.88
# NO2     92.33
# CO       8.83
# O3     107.68

# %%
full_dates = pd.date_range(hyd.index.min(), hyd.index.max(), freq='D')
hyd = hyd.reindex(full_dates)
hyd.index.name = 'Date'

# %%
missing_before = hyd.isna().sum()
print(missing_before)

hyd = hyd.interpolate(method='time', limit=2)

hyd = hyd.dropna(subset=['AQI'])
missing_after = hyd.isna().sum()

hyd.head()

print(pd.DataFrame({
    'before': missing_before,
    'after': missing_after
}))
# Out:
# AQI        0
# PM2.5      0
# PM10     224
# NO2        0
# CO         0
# O3         0
# dtype: int64
#        before  after
# AQI         0      0
# PM2.5       0      0
# PM10      224    219
# NO2         0      0
# CO          0      0
# O3          0      0
